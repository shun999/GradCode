# %%
import pandas as pd

# %%
df = pd.read_excel("E:\実験\実験結果\卒研B\データセット/1. 欠損値+不要行削除+列名英語化\欠損値処理後.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 538 entries, 0 to 537
# Data columns (total 99 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   SD_con                                                   538 non-null    float64
#  1   Interest                                                 538 non-null    float64
#  2   readers'_vocabulary                                      538 non-null    int64
#  3   Total_duration_of_fixations                              538 non-null    int64
#  4   Average_duration_of_fixations                            538 non-null    int64
#  5   Minimum_duration_of_fixations                            538 non-null    int64
#  6   Maximum_duration_of_fixations                            538 non-null    int64
#  7   Number_of_fixations                                      538 non-null    int64
# ...
