# %%
import pandas as pd

# %%
order1 = ["06", "01", "04", "02", "14", "11", "19", "09", "21", "22", "17", "23", "15", "18", "10", "24", "07", "25"]
order2 = ["26", "27", "45", "36", "29", "33", "46", "42"]

# %%
df = pd.DataFrame()

# %%
dfadd = pd.DataFrame()

# %%
dfadd
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in order2:
    # df = pd.read_csv("C:\WorkSpace\Practice\コサイン類似度\norm_result01.csv")
    # print(type(i))
    dfadd = pd.read_csv("C:\WorkSpace\Practice\コサイン類似度/avecossim_result" + i + ".csv")
    df = pd.concat([df, dfadd], axis=0, ignore_index=True)

# %%
df.to_csv("C:\WorkSpace\Practice\コサイン類似度\merge_avecossim2.csv")
