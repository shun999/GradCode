# %%
import pandas as pd
import os

# %%
df1 = pd.read_excel("C:/Users/thisi/OneDrive/共有ファイル/卒研B/卒研B結果/特徴量重要度/SFS/全体.xlsx")
df2 = pd.read_excel("C:/Users/thisi/OneDrive/共有ファイル/卒研B/卒研B結果/特徴量重要度/SFS/母語話者.xlsx")
df3 = pd.read_excel("C:/Users/thisi/OneDrive/共有ファイル/卒研B/卒研B結果/特徴量重要度/SFS/漢字文化圏非母語話者.xlsx")
df4 = pd.read_excel("C:/Users/thisi/OneDrive/共有ファイル/卒研B/卒研B結果/特徴量重要度/SFS/非漢字文化圏非母語話者.xlsx")

# %%
df1["PFI"][0]

for model, dict in df1["PFI"].items():
    print(f"{model}")
    for feature, importance in dict.items():
        print(importance)
# Out:
# 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 5
#       3 for model, dict in df1["PFI"].items():
#       4     print(f"{model}")
# ----> 5     for feature, importance in dict.items():
#       6         print(importance)
#
# AttributeError: 'str' object has no attribute 'items'

# %%
df1
# Out:
#   model                                                PFI  \
# 0   log  {'Average_duration_of_Visit_per_characters': -...
# 1    rf  {'Average_duration_of_Visit_per_characters': 0...
# 2    gb  {'Average_duration_of_Visit_per_characters': 0...
# 3   svm  {'Average_duration_of_Visit_per_characters': 0...
# 4   knn  {'Average_duration_of_Visit_per_characters': 0...
# 5   mlp  {'Average_duration_of_Visit_per_characters': 6...
# 6    nb  {'Average_duration_of_Visit_per_characters': 0...
#
#                                                 SHAP
# 0  {'Average_duration_of_Visit_per_characters': -...
# 1  {'Average_duration_of_Visit_per_characters': 0...
# 2  {'Average_duration_of_Visit_per_characters': 5...
# 3  {'Average_duration_of_Visit_per_characters': 1...
# 4  {'Average_duration_of_Visit_per_characters': 4...
# 5  {'Average_duration_of_Visit_per_characters': 1...
# 6  {'Average_duration_of_Visit_per_characters': 0...

# %%
pfi = {}
for i, importance in df1["PFI"].items():
    print(importance)
# Out:
# {'Average_duration_of_Visit_per_characters': -0.00046511627906977717, 'Maximum_duration_of_Visit': 0.05488372093023255, 'Number_of_Visits_per_characters': 0.0060465116279069695, 'Time_to_entry_saccade': 0.014883720930232536, 'Selective_regression-path_duration': 0.010697674418604674, 'Percentage_of_katakana_verb_numerator': 0.00046511627906977717, 'Number_of_extra_difficulty_kanzi_words': 0.0, 'Percentage_of_regular_difficulty_kanzi_words': 0.005116279069767482}
# {'Average_duration_of_Visit_per_characters': 0.0, 'Maximum_duration_of_Visit': 0.0, 'Number_of_Visits_per_characters': 0.0, 'Time_to_entry_saccade': 0.0, 'Selective_regression-path_duration': 0.0, 'Percentage_of_katakana_verb_numerator': 0.0, 'Number_of_extra_difficulty_kanzi_words': 0.0, 'Percentage_of_regular_difficulty_kanzi_words': 0.0}
# ...

# %%
df1["PFI"][0].split(":")[0][1:]
# Out:
# "'Average_duration_of_Visit_per_characters'"
