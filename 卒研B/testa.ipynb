# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/thisi/OneDrive/共有ファイル/リモートデスクトップ/データセット/0. データセット原本/データセット原本_完全版.csv")

# %%
group = df.groupby("読者の語彙量")

# %%
sum_value = group["文章"].nunique()
print(sum_value)
# Out:
# 読者の語彙量
# 19289    4
# 28416    4
# 59315    5
# 59378    2
# 67026    4
# 67528    7
# Name: 文章, dtype: int64
