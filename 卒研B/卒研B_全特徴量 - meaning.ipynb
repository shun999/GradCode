# %%
# 使用するモデルのインポート
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB

# %%
# その他のモジュールのインポート
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV, cross_val_predict, cross_val_score
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, 
                             confusion_matrix, ConfusionMatrixDisplay)
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from scipy.stats import uniform, randint, expon
import random

# %%
# ファイルの読み込み、データの格納・欠損値処理・確認
# file_path = "C:/Users/thisi/OneDrive/共有ファイル/リモートデスクトップ/ビニング処理_卒研A.csv"
# file_path = "E:/実験/実験結果/卒研B/データセット/2. 不要特徴量削除/2.不要特徴量削除後 分類テスト.csv"
# file_path = "C:/Users/81806/OneDrive/共有ファイル/リモートデスクトップ/データセット/2. 不要特徴量削除/2.不要特徴量削除後 分類テスト.csv"
file_path =  "C:/Users/thisi/OneDrive/共有ファイル/リモートデスクトップ/vif_result.csv"
target_column = "SD_dis"
data = pd.read_csv(file_path)
data = data.drop(columns=["SD_con", "Minimum_duration_of_whole_fixations", "Duration_of_first_Visit", "First-pass_first_fixation_duration", "Cossim_model6"])
data = data.fillna(data.mean())
data.info()
X = data.drop(columns=[target_column])
y = data[target_column]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 538 entries, 0 to 537
# Data columns (total 53 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   SD_dis                                                   538 non-null    int64
#  1   Interest                                                 538 non-null    float64
#  2   readers'_vocabulary                                      538 non-null    float64
#  3   Average_duration_of_fixations                            538 non-null    float64
#  4   Minimum_duration_of_fixations                            538 non-null    float64
#  5   Maximum_duration_of_fixations                            538 non-null    float64
#  6   Duration_of_first_fixation                               538 non-null    float64
#  7   Average_pupil_diameter                                   538 non-null    float64
#  8   Average_duration_of_Visit_per_characters                 538 non-null    float64
#  9   Minimum_duration_of_Visit                                538 non-null    float64
#  10  Maximum_duration_of_Visit                                538 non-null    float64
#  11  Number_of_Visits                                         538 non-null    float64
#  12  Number_of_Visits_per_characters                          538 non-null    float64
#  13  Number_of_saccades_in_AOI                                538 non-null    float64
#  14  Time_to_entry_saccade                                    538 non-null    float64
#  15  Time_to_exit_saccade                                     538 non-null    float64
#  16  Peak_velocity_of_entry_saccade                           538 non-null    float64
#  17  Peak_velocity_of_exit_saccade                            538 non-null    float64
#  18  First-pass_first_fixation_duration_per_characters        538 non-null    float64
#  19  First-pass_duration                                      538 non-null    float64
#  20  First-pass_duration_per_characters                       538 non-null    float64
#  21  Selective_regression-path_duration                       538 non-null    float64
#  22  Regression-path_duration                                 538 non-null    float64
#  23  Re-reading_duration_per_characters                       538 non-null    float64
#  24  Number_of_regression                                     538 non-null    float64
#  25  Percentage_of_katakana_verb_numerator                    538 non-null    float64
#  26  Percentage_of_katakana_noun                              538 non-null    float64
#  27  Percentage_of_katakana_noun_numerator                    538 non-null    float64
#  28  Number_of_easy_words                                     538 non-null    float64
#  29  Percentage_of_easy_words                                 538 non-null    float64
#  30  Percentage_of_kanzi                                      538 non-null    float64
#  31  Percentage_of_low_difficulty_kanzi_words                 538 non-null    float64
#  32  Number_of_low_difficulty_kanzi_words                     538 non-null    float64
#  33  Percentage_of_extra_difficulty_kanzi_words               538 non-null    float64
#  34  Number_of_extra_difficulty_kanzi_words                   538 non-null    float64
#  35  Percentage_of_regular_difficulty_kanzi_words             538 non-null    float64
#  36  Number_of_regular_difficulty_kanzi_words                 538 non-null    float64
#  37  Percentage_of_high_difficulty_kanzi_words                538 non-null    float64
#  38  Number_of_high_difficulty_kanzi_words                    538 non-null    float64
#  39  Percentage_of_low_difficulty_kanzis                      538 non-null    float64
#  40  Percentage_of_extra_difficulty_kanzis                    538 non-null    float64
#  41  Number_of_extra_difficulty_kanzis                        538 non-null    float64
#  42  Percentage_of_regular_difficulty_kanzis                  538 non-null    float64
#  43  Number_of_regular_difficulty_kanzis                      538 non-null    float64
#  44  Percentage_of_Chinese_words_verb                         538 non-null    float64
#  45  Percentage_of_Chinese_words_noun                         538 non-null    float64
#  46  Average_length_of_compund_nouns                          538 non-null    float64
#  47  Number_of_characters_of_adnominal_modification           538 non-null    float64
#  48  Percentage_of_adnominal_modification_out_of_total_nouns  538 non-null    float64
#  49  Number_of_adnominal_modification_out_of_total_nouns      538 non-null    float64
#  50  Percentage_of_frequent_words                             538 non-null    float64
#  51  Norm_model6                                              538 non-null    float64
#  52  Avecossim_model6                                         538 non-null    float64
# dtypes: float64(52), int64(1)
# memory usage: 222.9 KB

# %%
# データの可視化
plt.figure(figsize=(50, 40))
corr_matrix = data.corr('pearson')
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# # データの可視化
# plt.figure(figsize=(50, 40))
# corr_matrix = data.corr('spearman')
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# plt.title("Correlation Matrix")
# plt.show()

# # 散布図行列は時間かかるのでやりたいときだけ
# sns.pairplot(data)
# plt.title("Scatter Plot Matrix")
# plt.show()

# %%
# # 特徴量選択
# sfs = SFS(GradientBoostingClassifier(),
#           k_features="best",
#           forward = False,
#           floating= True,
#           scoring = 'accuracy',
#           cv = 3,
#           n_jobs= -1)

# sfs = sfs.fit(X, y)

# # 選択された特徴量の表示
# selected_features = sfs.k_feature_names_
# selected_features

# %%
# specific_feature = ['Maximum_duration_of_Visit',
#  'Peak_velocity_of_entry_saccade',
#  'First-pass_first_fixation_duration_per_characters',
#  'Percentage_of_katakana_noun',
#  'Percentage_of_extra_difficulty_kanzi_words',
#  'Number_of_regular_difficulty_kanzi_words',
#  'Number_of_extra_difficulty_kanzis',
#  'Cossim_model6']

# sfs_model = "None"

# type(specific_feature)

# %%
selected_features = X.columns
sfs = "None"
# selected_features = specific_feature

# 選択された特徴量のみをXに指定
X_slected = X[list(selected_features)]
X_slected.head()
# Out:
#    Interest  readers'_vocabulary  Average_duration_of_fixations  \
# 0  0.375212             0.761595                      -0.351952
# 1  0.375212             0.761595                      -0.185476
# 2  0.375212             0.761595                       0.169674
# 3  0.375212             0.761595                      -0.129983
# 4  0.375212             0.761595                      -0.474034
#
#    Minimum_duration_of_fixations  Maximum_duration_of_fixations  \
# 0                      -0.097800                       0.199184
# 1                       0.239483                      -0.567183
# 2                      -0.586860                       0.187096
# 3                      -0.536267                       0.182261
# 4                      -0.215849                      -0.424547
#
#    Duration_of_first_fixation  Average_pupil_diameter  \
# 0                   -0.600746               -1.170699
# 1                   -0.658071               -0.462425
# 2                    0.187480               -0.441221
# 3                    0.366622               -0.534291
# 4                   -0.536254               -0.199843
#
#    Average_duration_of_Visit_per_characters  Minimum_duration_of_Visit  \
# 0                                 -0.295523                   0.754565
# 1                                  0.888256                  -0.507392
# 2                                 -0.301747                  -0.459777
# 3                                 -0.470714                  -0.460434
# 4                                 -0.261558                  -0.377026
#
#    Maximum_duration_of_Visit  ...  Number_of_regular_difficulty_kanzis  \
# 0                  -0.343989  ...                            -0.232193
# 1                   1.100091  ...                            -0.832768
# 2                   0.027721  ...                            -0.832768
# 3                   0.919100  ...                            -0.832768
# 4                   0.005775  ...                             0.968958
#
#    Percentage_of_Chinese_words_verb  Percentage_of_Chinese_words_noun  \
# 0                         -0.100555                          0.959721
# 1                          3.798454                          1.083235
# 2                          3.798454                          0.877378
# 3                          2.336325                          0.300979
# 4                          0.829890                          1.042064
#
#    Average_length_of_compund_nouns  \
# 0                         0.896480
# 1                         0.695224
# 2                         1.097736
# 3                         0.828053
# 4                         0.695224
#
#    Number_of_characters_of_adnominal_modification  \
# 0                                        0.350212
# 1                                       -0.551506
# 2                                        0.214954
# 3                                        2.063475
# 4                                        0.755984
#
#    Percentage_of_adnominal_modification_out_of_total_nouns  \
# 0                                           1.053415
# 1                                          -0.276486
# 2                                          -0.276486
# 3                                          -1.074427
# 4                                          -1.074427
#
#    Number_of_adnominal_modification_out_of_total_nouns  \
# 0                                           2.269788
# 1                                          -0.660962
# 2                                           0.315954
# 3                                          -0.660962
# 4                                          -0.660962
#
#    Percentage_of_frequent_words  Norm_model6  Avecossim_model6
# 0                      1.304719     0.224689          0.071816
# 1                     -0.723448    -0.891166          1.271223
# 2                      0.049187     0.729960          0.635161
# 3                      0.338925     0.512859         -0.094689
# 4                     -0.337130    -0.138019          0.905471
#
# [5 rows x 52 columns]

# %%
# 選択された特徴量でモデル構築
X_train, X_test, y_train, y_test = train_test_split(X_slected, y, test_size=0.2, shuffle=True, random_state=42, stratify=y)

# 標準化
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# モデルの構築
base_models = [
        ('log', LogisticRegression(random_state=42)),
        ('rf', RandomForestClassifier(random_state=42)),
        ('gb', GradientBoostingClassifier(random_state=42)),
        ('svm', svm.SVC(kernel='rbf', probability=True, random_state=42)),
        ('knn', KNeighborsClassifier()),
        ('mlp', MLPClassifier(random_state=42)),
        ('nb', GaussianNB())
    ]

param_dist = {
    'log__penalty': ["l2"],
    'log__C': randint(1, 3),
    'log__solver': ['lbfgs', 'sag', 'liblinear'],
    'log__max_iter': randint(50, 150),
    'rf__n_estimators': randint(50, 150),
    'rf__criterion': ['gini', 'entropy', 'log_loss'],
    'rf__max_depth': randint(5, 50),
    'rf__min_samples_split': randint(1, 3),
    'rf__min_samples_leaf': uniform(0.01, 1),
    'gb__n_estimators':randint(80, 200),
    'gb__learning_rate': uniform(0.01, 0.3),
    'gb__max_depth':randint(3, 10),
    'gb__min_samples_leaf':randint(1, 5),
    'gb__subsample':uniform(0.5, 1.0),
    'svm__C': uniform(0.01, 100),
    'svm__gamma': ['scale', 'auto', 0.01, 0.1, 1],
    'knn__n_neighbors':randint(2, 7),
    'knn__leaf_size':randint(10, 50),
    'mlp__hidden_layer_sizes': [(100,), (50,), (100, 50)],
    'mlp__alpha': uniform(0.0001, 0.01),
    'mlp__max_iter': randint(100, 300),
    'nb__var_smoothing': [1e-9, 5e-9, 1e-8],
    'final_estimator__C' : randint(1, 3),
    'final_estimator__max_iter' : randint(50, 150),
    'final_estimator__penalty' : ["l2"],
    'final_estimator__solver' : ['lbfgs', 'sag', 'liblinear']
}

meta_model = LogisticRegression(random_state=42)

stacking_model = StackingClassifier(estimators=base_models,
                                     final_estimator=meta_model,
                                       cv=5)

# %%
# ランダムサーチの実行
random_search = RandomizedSearchCV(estimator=stacking_model,
                                   param_distributions=param_dist,
                                   n_iter=100,
                                   cv=3,
                                   scoring='accuracy',
                                   random_state=42)

random_search.fit(X_train_scaled, y_train)
print(random_search.best_params_)
# Out:
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (180) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (241) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (102) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (153) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (107) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (182) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (182) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (182) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (182) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (182) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (182) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
#     return super().fit(X, y_encoded, sample_weight)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 224, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_base.py", line 40, in _fit_single_estimator
#     estimator.fit(X, y, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.3214407280098666 instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 672, in fit
#     return super().fit(X, y_encoded, sample_weight)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 224, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_base.py", line 40, in _fit_single_estimator
#     estimator.fit(X, y, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.3948166560605277 instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 672, in fit
#     return super().fit(X, y_encoded, sample_weight)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 224, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_base.py", line 40, in _fit_single_estimator
#     estimator.fit(X, y, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.3462452920190493 instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 672, in fit
#     return super().fit(X, y_encoded, sample_weight)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 224, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_base.py", line 40, in _fit_single_estimator
#     estimator.fit(X, y, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.4366056922949615 instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 672, in fit
#     return super().fit(X, y_encoded, sample_weight)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 224, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_base.py", line 40, in _fit_single_estimator
#     estimator.fit(X, y, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.104953922690541 instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 672, in fit
#     return super().fit(X, y_encoded, sample_weight)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py", line 224, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py", line 136, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_base.py", line 40, in _fit_single_estimator
#     estimator.fit(X, y, **fit_params)
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 1.2862759567570945 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.76278814        nan 0.76045714        nan        nan 0.75346413
#         nan 0.75113313        nan        nan        nan        nan
#         nan        nan 0.7511655         nan        nan        nan
#         nan        nan        nan        nan        nan 0.75346413
#         nan        nan        nan        nan        nan        nan
#         nan 0.75812613        nan        nan        nan 0.76045714
#         nan 0.75581132 0.76044095 0.75346413        nan 0.76278814
#  0.75579513        nan 0.75812613 0.75812613        nan        nan
#  0.75812613        nan 0.76278814 0.76045714        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.76278814        nan        nan        nan        nan        nan
#         nan        nan 0.75812613        nan        nan 0.75348032
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.76045714 0.75581132 0.75346413
#         nan        nan 0.75812613 0.75346413]
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# {'final_estimator__C': 2, 'final_estimator__max_iter': 96, 'final_estimator__penalty': 'l2', 'final_estimator__solver': 'sag', 'gb__learning_rate': 0.167317080798274, 'gb__max_depth': 6, 'gb__min_samples_leaf': 1, 'gb__n_estimators': 193, 'gb__subsample': 0.997011948821249, 'knn__leaf_size': 13, 'knn__n_neighbors': 2, 'log__C': 2, 'log__max_iter': 78, 'log__penalty': 'l2', 'log__solver': 'liblinear', 'mlp__alpha': 0.009561154621336327, 'mlp__hidden_layer_sizes': (50,), 'mlp__max_iter': 209, 'nb__var_smoothing': 5e-09, 'rf__criterion': 'gini', 'rf__max_depth': 27, 'rf__min_samples_leaf': 0.9889314356159612, 'rf__min_samples_split': 2, 'rf__n_estimators': 99, 'svm__C': 86.70937600115235, 'svm__gamma': 'scale'}
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# 最終モデルの構築
final_model = random_search.best_estimator_
final_model.fit(X_train_scaled, y_train)
# Out:
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (209) reached and the optimization hasn't converged yet.
#   warnings.warn(
# StackingClassifier(cv=5,
#                    estimators=[('log',
#                                 LogisticRegression(C=2, max_iter=78,
#                                                    random_state=42,
#                                                    solver='liblinear')),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=27,
#                                                        min_samples_leaf=0.9889314356159612,
#                                                        n_estimators=99,
#                                                        random_state=42)),
#                                ('gb',
#                                 GradientBoostingClassifier(learning_rate=0.167317080798274,
#                                                            max_depth=6,
#                                                            n_estimators=193,
#                                                            random_state=42,
#                                                            subsample=0.9...),
#                                ('svm',
#                                 SVC(C=86.70937600115235, probability=True,
#                                     random_state=42)),
#                                ('knn',
#                                 KNeighborsClassifier(leaf_size=13,
#                                                      n_neighbors=2)),
#                                ('mlp',
#                                 MLPClassifier(alpha=0.009561154621336327,
#                                               hidden_layer_sizes=(50,),
#                                               max_iter=209, random_state=42)),
#                                ('nb', GaussianNB(var_smoothing=5e-09))],
#                    final_estimator=LogisticRegression(C=2, max_iter=96,
#                                                       random_state=42,
#                                                       solver='sag'))

# %%
# 最終モデルのテストデータへの適用および性能評価
y_pred = final_model.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, average='weighted'))
print("Recall:", recall_score(y_test, y_pred, average='weighted'))
print("F1 Score:", f1_score(y_test, y_pred, average='weighted'))

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(y))
disp.plot(cmap='Blues')
plt.show()
# Out:
# Accuracy: 0.8148148148148148
# Precision: 0.8053626543209875
# Recall: 0.8148148148148148
# F1 Score: 0.7879843178483036

# %%
# Compare base models
Model_accuracy = {}
for name, model in random_search.best_estimator_.estimators:
    scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')
    Model_accuracy[f"{name}"] = scores.mean()
    print(f"{name} Accuracy: {scores.mean():.4f} (+/- {scores.std():.4f})")

# Evaluate stacking model
stacking_scores = cross_val_score(final_model, X, y, cv=5, scoring='accuracy')
print(f"Stacking Model Accuracy: {stacking_scores.mean():.4f} (+/- {stacking_scores.std():.4f})")
# Out:
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# log Accuracy: 0.6332 (+/- 0.1934)
# rf Accuracy: 0.7621 (+/- 0.0035)
# gb Accuracy: 0.5943 (+/- 0.1343)
# svm Accuracy: 0.7621 (+/- 0.0035)
# knn Accuracy: 0.7025 (+/- 0.0445)
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (111) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# mlp Accuracy: 0.6370 (+/- 0.1541)
# nb Accuracy: 0.3622 (+/- 0.1674)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 9
#       6     print(f"{name} Accuracy: {scores.mean():.4f} (+/- {scores.std():.4f})")
#       8 # Evaluate stacking model
# ----> 9 stacking_scores = cross_val_score(final_model, X, y, cv=5, scoring='accuracy')
#      10 print(f"Stacking Model Accuracy: {stacking_scores.mean():.4f} (+/- {stacking_scores.std():.4f})")
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_validation.py:712, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     709 # To ensure multimetric format is not supported
#     710 scorer = check_scoring(estimator, scoring=scoring)
# --> 712 cv_results = cross_validate(
#     713     estimator=estimator,
#     714     X=X,
#     715     y=y,
#     716     groups=groups,
#     717     scoring={"score": scorer},
#     718     cv=cv,
#     719     n_jobs=n_jobs,
#     720     verbose=verbose,
#     721     fit_params=fit_params,
#     722     params=params,
#     723     pre_dispatch=pre_dispatch,
#     724     error_score=error_score,
#     725 )
#     726 return cv_results["test_score"]
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_validation.py:423, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     420 # We clone the estimator to make sure that all the folds are
#     421 # independent, and that it is pickle-able.
#     422 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 423 results = parallel(
#     424     delayed(_fit_and_score)(
#     425         clone(estimator),
#     426         X,
#     427         y,
#     428         scorer=scorers,
#     429         train=train,
#     430         test=test,
#     431         verbose=verbose,
#     432         parameters=None,
#     433         fit_params=routed_params.estimator.fit,
#     434         score_params=routed_params.scorer.score,
#     435         return_train_score=return_train_score,
#     436         return_times=True,
#     437         return_estimator=return_estimator,
#     438         error_score=error_score,
#     439     )
#     440     for train, test in indices
#     441 )
#     443 _warn_or_raise_about_fit_failures(results, error_score)
#     445 # For callable scoring, the return type is only know after calling. If the
#     446 # return type is a dictionary, the error scores can now be inserted with
#     447 # the correct key.
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py:672, in StackingClassifier.fit(self, X, y, sample_weight)
#     670     self.classes_ = self._label_encoder.classes_
#     671     y_encoded = self._label_encoder.transform(y)
# --> 672 return super().fit(X, y_encoded, sample_weight)
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_stacking.py:224, in _BaseStacking.fit(self, X, y, sample_weight)
#     219             self.estimators_.append(estimator)
#     220 else:
#     221     # Fit the base estimators on the whole training data. Those
#     222     # base estimators will be used in transform, predict, and
#     223     # predict_proba. They are exposed publicly.
# --> 224     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     225         delayed(_fit_single_estimator)(clone(est), X, y, fit_params)
#     226         for est in all_estimators
#     227         if est != "drop"
#     228     )
#     230 self.named_estimators_ = Bunch()
#     231 est_fitted_idx = 0
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_base.py:40, in _fit_single_estimator(estimator, X, y, fit_params, message_clsname, message)
#      38 else:
#      39     with _print_elapsed_time(message_clsname, message):
# ---> 40         estimator.fit(X, y, **fit_params)
#      41 return estimator
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_gb.py:783, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     780     self._resize_state()
#     782 # fit the boosting stages
# --> 783 n_stages = self._fit_stages(
#     784     X_train,
#     785     y_train,
#     786     raw_predictions,
#     787     sample_weight_train,
#     788     self._rng,
#     789     X_val,
#     790     y_val,
#     791     sample_weight_val,
#     792     begin_at_stage,
#     793     monitor,
#     794 )
#     796 # change shape of arrays after fit (early-stopping or additional ests)
#     797 if n_stages != self.estimators_.shape[0]:
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_gb.py:879, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     872         initial_loss = factor * self._loss(
#     873             y_true=y_oob_masked,
#     874             raw_prediction=raw_predictions[~sample_mask],
#     875             sample_weight=sample_weight_oob_masked,
#     876         )
#     878 # fit next stage of trees
# --> 879 raw_predictions = self._fit_stage(
#     880     i,
#     881     X,
#     882     y,
#     883     raw_predictions,
#     884     sample_weight,
#     885     sample_mask,
#     886     random_state,
#     887     X_csc=X_csc,
#     888     X_csr=X_csr,
#     889 )
#     891 # track loss
#     892 if do_oob:
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\ensemble\_gb.py:490, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     487     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     489 X = X_csc if X_csc is not None else X
# --> 490 tree.fit(
#     491     X, neg_g_view[:, k], sample_weight=sample_weight, check_input=False
#     492 )
#     494 # update tree leaves
#     495 X_for_tree_update = X_csr if X_csr is not None else X
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\tree\_classes.py:1377, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1347 @_fit_context(prefer_skip_nested_validation=True)
#    1348 def fit(self, X, y, sample_weight=None, check_input=True):
#    1349     """Build a decision tree regressor from the training set (X, y).
#    1350
#    1351     Parameters
#    (...)
#    1374         Fitted estimator.
#    1375     """
# -> 1377     super()._fit(
#    1378         X,
#    1379         y,
#    1380         sample_weight=sample_weight,
#    1381         check_input=check_input,
#    1382     )
#    1383     return self
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# 各モデルの特徴量重要度をPFIとSHAPで算出
from sklearn.inspection import permutation_importance
import shap

# 訓練データ(X_train, y_train)を用いてモデルをフィットします
for name, model in random_search.best_estimator_.estimators:
    model.fit(X_train, y_train)

PFIs = {}
for name, model in random_search.best_estimator_.estimators:
    pfi = permutation_importance(model, X_train, y_train, random_state=42)
    # 特徴量の名前と重要度をセットにした辞書を作成
    feature_importances = {X_train.columns[i]: pfi.importances_mean[i] for i in range(len(X_train.columns))}
    PFIs[f'{name}'] = feature_importances

# 結果の確認
for model_name, importances in PFIs.items():
    print(f"Model: {model_name}")
    for feature, importance in importances.items():
        print(f"  {feature}: {importance:.4f}")


SHAPs = {}
for name, model in random_search.best_estimator_.estimators:
    explainer = shap.KernelExplainer(model.predict_proba, X_train_scaled)
    shap_values = explainer.shap_values(X_train_scaled)
    shap_importances = np.mean(shap_values, axis=(0, 2))
    shaps = {X_train.columns[i]: shap_importances[i] for i in range(len(X_train.columns))}
    # SHAPs[f'{name}'] = np.mean(shap_values, axis=(0, 2))
    shap.summary_plot(np.mean(shap_values, axis=2), X_train_scaled, feature_names=selected_features)
    SHAPs[f'{name}'] = shaps

# 結果を表示
for model_name, importances in SHAPs.items():
    print(f"Model {model_name}")
    for feature, importance in importances.items():
        print(f"  {feature}: {importance}")
# Out:
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\WorkSpace\Practice\env3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (162) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Using 430 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# Model: log
#   Interest: 0.0326
#   readers'_vocabulary: 0.0353
#   Average_duration_of_fixations: 0.0000
#   Minimum_duration_of_fixations: 0.0130
#   Maximum_duration_of_fixations: -0.0014
#   Duration_of_first_fixation: 0.0056
#   Average_pupil_diameter: 0.0098
#   Average_duration_of_Visit_per_characters: -0.0023
#   Minimum_duration_of_Visit: 0.0116
#   Maximum_duration_of_Visit: 0.0321
#   Number_of_Visits: 0.0247
#   Number_of_Visits_per_characters: 0.0028
#   Number_of_saccades_in_AOI: -0.0019
#   Time_to_entry_saccade: 0.0037
#   Time_to_exit_saccade: 0.0056
#   Peak_velocity_of_entry_saccade: 0.0009
#   Peak_velocity_of_exit_saccade: 0.0265
#   First-pass_first_fixation_duration_per_characters: 0.0065
#   First-pass_duration: 0.0037
#   First-pass_duration_per_characters: 0.0093
#   Selective_regression-path_duration: 0.0200
#   Regression-path_duration: 0.0121
#   Re-reading_duration_per_characters: -0.0005
#   Number_of_regression: 0.0172
#   Percentage_of_katakana_verb_numerator: 0.0005
#   Percentage_of_katakana_noun: 0.0033
#   Percentage_of_katakana_noun_numerator: 0.0051
#   Number_of_easy_words: 0.0237
#   Percentage_of_easy_words: 0.0340
#   Percentage_of_kanzi: 0.0098
#   Percentage_of_low_difficulty_kanzi_words: 0.0228
#   Number_of_low_difficulty_kanzi_words: 0.0042
#   Percentage_of_extra_difficulty_kanzi_words: 0.0033
#   Number_of_extra_difficulty_kanzi_words: 0.0000
#   Percentage_of_regular_difficulty_kanzi_words: -0.0005
#   Number_of_regular_difficulty_kanzi_words: 0.0051
#   Percentage_of_high_difficulty_kanzi_words: 0.0460
#   Number_of_high_difficulty_kanzi_words: 0.0260
#   Percentage_of_low_difficulty_kanzis: 0.0093
#   Percentage_of_extra_difficulty_kanzis: 0.0000
#   Number_of_extra_difficulty_kanzis: 0.0056
#   Percentage_of_regular_difficulty_kanzis: 0.0037
#   Number_of_regular_difficulty_kanzis: 0.0205
#   Percentage_of_Chinese_words_verb: 0.0112
#   Percentage_of_Chinese_words_noun: 0.0005
#   Average_length_of_compund_nouns: 0.0056
#   Number_of_characters_of_adnominal_modification: 0.0219
#   Percentage_of_adnominal_modification_out_of_total_nouns: 0.0028
#   Number_of_adnominal_modification_out_of_total_nouns: 0.0233
#   Percentage_of_frequent_words: 0.0098
#   Cossim_model6: 0.0153
#   Norm_model6: 0.0237
#   Avecossim_model6: 0.0000
# Model: rf
#   Interest: 0.0000
#   readers'_vocabulary: 0.0000
#   Average_duration_of_fixations: 0.0000
#   Minimum_duration_of_fixations: 0.0000
#   Maximum_duration_of_fixations: 0.0000
#   Duration_of_first_fixation: 0.0000
#   Average_pupil_diameter: 0.0000
#   Average_duration_of_Visit_per_characters: 0.0000
#   Minimum_duration_of_Visit: 0.0000
#   Maximum_duration_of_Visit: 0.0000
#   Number_of_Visits: 0.0000
#   Number_of_Visits_per_characters: 0.0000
#   Number_of_saccades_in_AOI: 0.0000
#   Time_to_entry_saccade: 0.0000
#   Time_to_exit_saccade: 0.0000
#   Peak_velocity_of_entry_saccade: 0.0000
#   Peak_velocity_of_exit_saccade: 0.0000
#   First-pass_first_fixation_duration_per_characters: 0.0000
#   First-pass_duration: 0.0000
#   First-pass_duration_per_characters: 0.0000
#   Selective_regression-path_duration: 0.0000
#   Regression-path_duration: 0.0000
#   Re-reading_duration_per_characters: 0.0000
#   Number_of_regression: 0.0000
#   Percentage_of_katakana_verb_numerator: 0.0000
#   Percentage_of_katakana_noun: 0.0000
#   Percentage_of_katakana_noun_numerator: 0.0000
#   Number_of_easy_words: 0.0000
#   Percentage_of_easy_words: 0.0000
#   Percentage_of_kanzi: 0.0000
#   Percentage_of_low_difficulty_kanzi_words: 0.0000
#   Number_of_low_difficulty_kanzi_words: 0.0000
#   Percentage_of_extra_difficulty_kanzi_words: 0.0000
#   Number_of_extra_difficulty_kanzi_words: 0.0000
#   Percentage_of_regular_difficulty_kanzi_words: 0.0000
#   Number_of_regular_difficulty_kanzi_words: 0.0000
#   Percentage_of_high_difficulty_kanzi_words: 0.0000
#   Number_of_high_difficulty_kanzi_words: 0.0000
#   Percentage_of_low_difficulty_kanzis: 0.0000
#   Percentage_of_extra_difficulty_kanzis: 0.0000
#   Number_of_extra_difficulty_kanzis: 0.0000
#   Percentage_of_regular_difficulty_kanzis: 0.0000
#   Number_of_regular_difficulty_kanzis: 0.0000
#   Percentage_of_Chinese_words_verb: 0.0000
#   Percentage_of_Chinese_words_noun: 0.0000
#   Average_length_of_compund_nouns: 0.0000
#   Number_of_characters_of_adnominal_modification: 0.0000
#   Percentage_of_adnominal_modification_out_of_total_nouns: 0.0000
#   Number_of_adnominal_modification_out_of_total_nouns: 0.0000
#   Percentage_of_frequent_words: 0.0000
#   Cossim_model6: 0.0000
#   Norm_model6: 0.0000
#   Avecossim_model6: 0.0000
# Model: gb
#   Interest: 0.0177
#   readers'_vocabulary: 0.0000
#   Average_duration_of_fixations: 0.0000
#   Minimum_duration_of_fixations: 0.0000
#   Maximum_duration_of_fixations: 0.0000
#   Duration_of_first_fixation: 0.0009
#   Average_pupil_diameter: 0.0000
#   Average_duration_of_Visit_per_characters: 0.0000
#   Minimum_duration_of_Visit: 0.0000
#   Maximum_duration_of_Visit: 0.0079
#   Number_of_Visits: 0.0019
#   Number_of_Visits_per_characters: 0.0000
#   Number_of_saccades_in_AOI: 0.0000
#   Time_to_entry_saccade: 0.0000
#   Time_to_exit_saccade: 0.0000
#   Peak_velocity_of_entry_saccade: 0.0000
#   Peak_velocity_of_exit_saccade: 0.0014
#   First-pass_first_fixation_duration_per_characters: 0.0000
#   First-pass_duration: 0.0000
#   First-pass_duration_per_characters: 0.0000
#   Selective_regression-path_duration: 0.0000
#   Regression-path_duration: 0.0000
#   Re-reading_duration_per_characters: 0.0000
#   Number_of_regression: 0.0000
#   Percentage_of_katakana_verb_numerator: 0.0000
#   Percentage_of_katakana_noun: 0.0000
#   Percentage_of_katakana_noun_numerator: 0.0000
#   Number_of_easy_words: 0.0000
#   Percentage_of_easy_words: 0.0000
#   Percentage_of_kanzi: 0.0000
#   Percentage_of_low_difficulty_kanzi_words: 0.0000
#   Number_of_low_difficulty_kanzi_words: 0.0000
#   Percentage_of_extra_difficulty_kanzi_words: 0.0000
#   Number_of_extra_difficulty_kanzi_words: 0.0000
#   Percentage_of_regular_difficulty_kanzi_words: 0.0000
#   Number_of_regular_difficulty_kanzi_words: 0.0000
#   Percentage_of_high_difficulty_kanzi_words: 0.0000
#   Number_of_high_difficulty_kanzi_words: 0.0000
#   Percentage_of_low_difficulty_kanzis: 0.0000
#   Percentage_of_extra_difficulty_kanzis: 0.0000
#   Number_of_extra_difficulty_kanzis: 0.0000
#   Percentage_of_regular_difficulty_kanzis: 0.0000
#   Number_of_regular_difficulty_kanzis: 0.0000
#   Percentage_of_Chinese_words_verb: 0.0000
#   Percentage_of_Chinese_words_noun: 0.0000
#   Average_length_of_compund_nouns: 0.0000
#   Number_of_characters_of_adnominal_modification: 0.0000
#   Percentage_of_adnominal_modification_out_of_total_nouns: 0.0000
#   Number_of_adnominal_modification_out_of_total_nouns: 0.0000
#   Percentage_of_frequent_words: 0.0005
#   Cossim_model6: 0.0000
#   Norm_model6: 0.0009
#   Avecossim_model6: 0.0000
# Model: svm
#   Interest: 0.0260
#   readers'_vocabulary: 0.0051
#   Average_duration_of_fixations: 0.0005
#   Minimum_duration_of_fixations: 0.0019
#   Maximum_duration_of_fixations: 0.0000
#   Duration_of_first_fixation: 0.0060
#   Average_pupil_diameter: 0.0023
#   Average_duration_of_Visit_per_characters: 0.0023
#   Minimum_duration_of_Visit: 0.0037
#   Maximum_duration_of_Visit: 0.0005
#   Number_of_Visits: 0.0079
#   Number_of_Visits_per_characters: 0.0028
#   Number_of_saccades_in_AOI: 0.0023
#   Time_to_entry_saccade: 0.0014
#   Time_to_exit_saccade: 0.0014
#   Peak_velocity_of_entry_saccade: 0.0014
#   Peak_velocity_of_exit_saccade: 0.0019
#   First-pass_first_fixation_duration_per_characters: 0.0000
#   First-pass_duration: 0.0009
#   First-pass_duration_per_characters: 0.0000
#   Selective_regression-path_duration: 0.0028
#   Regression-path_duration: 0.0000
#   Re-reading_duration_per_characters: 0.0005
#   Number_of_regression: 0.0000
#   Percentage_of_katakana_verb_numerator: 0.0028
#   Percentage_of_katakana_noun: 0.0060
#   Percentage_of_katakana_noun_numerator: 0.0005
#   Number_of_easy_words: 0.0121
#   Percentage_of_easy_words: 0.0042
#   Percentage_of_kanzi: 0.0000
#   Percentage_of_low_difficulty_kanzi_words: 0.0009
#   Number_of_low_difficulty_kanzi_words: 0.0074
#   Percentage_of_extra_difficulty_kanzi_words: 0.0000
#   Number_of_extra_difficulty_kanzi_words: 0.0000
#   Percentage_of_regular_difficulty_kanzi_words: 0.0005
#   Number_of_regular_difficulty_kanzi_words: 0.0000
#   Percentage_of_high_difficulty_kanzi_words: 0.0028
#   Number_of_high_difficulty_kanzi_words: 0.0065
#   Percentage_of_low_difficulty_kanzis: 0.0009
#   Percentage_of_extra_difficulty_kanzis: 0.0028
#   Number_of_extra_difficulty_kanzis: 0.0000
#   Percentage_of_regular_difficulty_kanzis: 0.0023
#   Number_of_regular_difficulty_kanzis: 0.0014
#   Percentage_of_Chinese_words_verb: 0.0023
#   Percentage_of_Chinese_words_noun: 0.0014
#   Average_length_of_compund_nouns: 0.0037
#   Number_of_characters_of_adnominal_modification: 0.0084
#   Percentage_of_adnominal_modification_out_of_total_nouns: 0.0033
#   Number_of_adnominal_modification_out_of_total_nouns: 0.0047
#   Percentage_of_frequent_words: 0.0023
#   Cossim_model6: 0.0028
#   Norm_model6: 0.0014
#   Avecossim_model6: 0.0028
# Model: knn
#   Interest: 0.0000
#   readers'_vocabulary: 0.0023
#   Average_duration_of_fixations: -0.0014
#   Minimum_duration_of_fixations: -0.0009
#   Maximum_duration_of_fixations: -0.0047
#   Duration_of_first_fixation: 0.0014
#   Average_pupil_diameter: 0.0023
#   Average_duration_of_Visit_per_characters: 0.0000
#   Minimum_duration_of_Visit: 0.0056
#   Maximum_duration_of_Visit: 0.0047
#   Number_of_Visits: 0.0005
#   Number_of_Visits_per_characters: 0.0009
#   Number_of_saccades_in_AOI: -0.0033
#   Time_to_entry_saccade: -0.0033
#   Time_to_exit_saccade: -0.0028
#   Peak_velocity_of_entry_saccade: -0.0033
#   Peak_velocity_of_exit_saccade: 0.0000
#   First-pass_first_fixation_duration_per_characters: 0.0005
#   First-pass_duration: 0.0051
#   First-pass_duration_per_characters: 0.0042
#   Selective_regression-path_duration: 0.0014
#   Regression-path_duration: -0.0014
#   Re-reading_duration_per_characters: -0.0079
#   Number_of_regression: 0.0028
#   Percentage_of_katakana_verb_numerator: 0.0000
#   Percentage_of_katakana_noun: 0.0019
#   Percentage_of_katakana_noun_numerator: 0.0014
#   Number_of_easy_words: 0.0005
#   Percentage_of_easy_words: 0.0042
#   Percentage_of_kanzi: 0.0023
#   Percentage_of_low_difficulty_kanzi_words: -0.0028
#   Number_of_low_difficulty_kanzi_words: -0.0023
#   Percentage_of_extra_difficulty_kanzi_words: 0.0000
#   Number_of_extra_difficulty_kanzi_words: 0.0000
#   Percentage_of_regular_difficulty_kanzi_words: 0.0023
#   Number_of_regular_difficulty_kanzi_words: 0.0019
#   Percentage_of_high_difficulty_kanzi_words: -0.0023
#   Number_of_high_difficulty_kanzi_words: 0.0023
#   Percentage_of_low_difficulty_kanzis: -0.0042
#   Percentage_of_extra_difficulty_kanzis: 0.0000
#   Number_of_extra_difficulty_kanzis: 0.0005
#   Percentage_of_regular_difficulty_kanzis: -0.0019
#   Number_of_regular_difficulty_kanzis: 0.0005
#   Percentage_of_Chinese_words_verb: 0.0014
#   Percentage_of_Chinese_words_noun: -0.0028
#   Average_length_of_compund_nouns: 0.0060
#   Number_of_characters_of_adnominal_modification: -0.0005
#   Percentage_of_adnominal_modification_out_of_total_nouns: -0.0005
#   Number_of_adnominal_modification_out_of_total_nouns: -0.0005
#   Percentage_of_frequent_words: -0.0005
#   Cossim_model6: 0.0014
#   Norm_model6: 0.0000
#   Avecossim_model6: 0.0009
# Model: mlp
#   Interest: 0.0609
#   readers'_vocabulary: 0.0423
#   Average_duration_of_fixations: 0.0047
#   Minimum_duration_of_fixations: 0.0093
#   Maximum_duration_of_fixations: 0.0126
#   Duration_of_first_fixation: 0.0195
#   Average_pupil_diameter: 0.0200
#   Average_duration_of_Visit_per_characters: 0.0093
#   Minimum_duration_of_Visit: 0.0158
#   Maximum_duration_of_Visit: 0.0381
#   Number_of_Visits: 0.0512
#   Number_of_Visits_per_characters: 0.0191
#   Number_of_saccades_in_AOI: 0.0112
#   Time_to_entry_saccade: 0.0126
#   Time_to_exit_saccade: 0.0191
#   Peak_velocity_of_entry_saccade: 0.0195
#   Peak_velocity_of_exit_saccade: 0.0312
#   First-pass_first_fixation_duration_per_characters: 0.0107
#   First-pass_duration: 0.0140
#   First-pass_duration_per_characters: 0.0181
#   Selective_regression-path_duration: 0.0191
#   Regression-path_duration: 0.0130
#   Re-reading_duration_per_characters: 0.0070
#   Number_of_regression: 0.0140
#   Percentage_of_katakana_verb_numerator: 0.0028
#   Percentage_of_katakana_noun: 0.0181
#   Percentage_of_katakana_noun_numerator: 0.0116
#   Number_of_easy_words: 0.0447
#   Percentage_of_easy_words: 0.0330
#   Percentage_of_kanzi: 0.0112
#   Percentage_of_low_difficulty_kanzi_words: 0.0163
#   Number_of_low_difficulty_kanzi_words: 0.0167
#   Percentage_of_extra_difficulty_kanzi_words: 0.0060
#   Number_of_extra_difficulty_kanzi_words: 0.0014
#   Percentage_of_regular_difficulty_kanzi_words: 0.0107
#   Number_of_regular_difficulty_kanzi_words: 0.0093
#   Percentage_of_high_difficulty_kanzi_words: 0.0326
#   Number_of_high_difficulty_kanzi_words: 0.0158
#   Percentage_of_low_difficulty_kanzis: 0.0274
#   Percentage_of_extra_difficulty_kanzis: 0.0056
#   Number_of_extra_difficulty_kanzis: 0.0028
#   Percentage_of_regular_difficulty_kanzis: 0.0065
#   Number_of_regular_difficulty_kanzis: 0.0121
#   Percentage_of_Chinese_words_verb: 0.0186
#   Percentage_of_Chinese_words_noun: 0.0181
#   Average_length_of_compund_nouns: 0.0074
#   Number_of_characters_of_adnominal_modification: 0.0186
#   Percentage_of_adnominal_modification_out_of_total_nouns: 0.0144
#   Number_of_adnominal_modification_out_of_total_nouns: 0.0391
#   Percentage_of_frequent_words: 0.0130
#   Cossim_model6: 0.0191
#   Norm_model6: 0.0209
#   Avecossim_model6: 0.0177
# Model: nb
#   Interest: 0.0014
#   readers'_vocabulary: -0.0033
#   Average_duration_of_fixations: -0.0005
#   Minimum_duration_of_fixations: 0.0009
#   Maximum_duration_of_fixations: -0.0019
#   Duration_of_first_fixation: 0.0019
#   Average_pupil_diameter: 0.0009
#   Average_duration_of_Visit_per_characters: 0.0009
#   Minimum_duration_of_Visit: 0.0009
#   Maximum_duration_of_Visit: 0.0000
#   Number_of_Visits: 0.0033
#   Number_of_Visits_per_characters: 0.0019
#   Number_of_saccades_in_AOI: 0.0014
#   Time_to_entry_saccade: 0.0009
#   Time_to_exit_saccade: 0.0005
#   Peak_velocity_of_entry_saccade: 0.0019
#   Peak_velocity_of_exit_saccade: -0.0005
#   First-pass_first_fixation_duration_per_characters: 0.0037
#   First-pass_duration: 0.0028
#   First-pass_duration_per_characters: 0.0028
#   Selective_regression-path_duration: 0.0028
#   Regression-path_duration: 0.0019
#   Re-reading_duration_per_characters: 0.0009
#   Number_of_regression: 0.0033
#   Percentage_of_katakana_verb_numerator: 0.0009
#   Percentage_of_katakana_noun: -0.0047
#   Percentage_of_katakana_noun_numerator: -0.0023
#   Number_of_easy_words: 0.0005
#   Percentage_of_easy_words: -0.0023
#   Percentage_of_kanzi: 0.0009
#   Percentage_of_low_difficulty_kanzi_words: 0.0000
#   Number_of_low_difficulty_kanzi_words: 0.0000
#   Percentage_of_extra_difficulty_kanzi_words: -0.0121
#   Number_of_extra_difficulty_kanzi_words: -0.0144
#   Percentage_of_regular_difficulty_kanzi_words: 0.0042
#   Number_of_regular_difficulty_kanzi_words: 0.0037
#   Percentage_of_high_difficulty_kanzi_words: -0.0014
#   Number_of_high_difficulty_kanzi_words: -0.0005
#   Percentage_of_low_difficulty_kanzis: -0.0005
#   Percentage_of_extra_difficulty_kanzis: -0.0293
#   Number_of_extra_difficulty_kanzis: -0.0344
#   Percentage_of_regular_difficulty_kanzis: 0.0005
#   Number_of_regular_difficulty_kanzis: 0.0023
#   Percentage_of_Chinese_words_verb: -0.0009
#   Percentage_of_Chinese_words_noun: 0.0005
#   Average_length_of_compund_nouns: -0.0009
#   Number_of_characters_of_adnominal_modification: -0.0005
#   Percentage_of_adnominal_modification_out_of_total_nouns: 0.0033
#   Number_of_adnominal_modification_out_of_total_nouns: -0.0023
#   Percentage_of_frequent_words: -0.0023
#   Cossim_model6: -0.0009
#   Norm_model6: -0.0033
#   Avecossim_model6: 0.0000
#  73%|███████▎  | 314/430 [23:33<08:42,  4.50s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 26
#      24 for name, model in random_search.best_estimator_.estimators:
#      25     explainer = shap.KernelExplainer(model.predict_proba, X_train_scaled)
# ---> 26     shap_values = explainer.shap_values(X_train_scaled)
#      27     shap_importances = np.mean(shap_values, axis=(0, 2))
#      28     shaps = {X_train.columns[i]: shap_importances[i] for i in range(len(X_train.columns))}
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\shap\explainers\_kernel.py:271, in KernelExplainer.shap_values(self, X, **kwargs)
#     269 if self.keep_index:
#     270     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 271 explanations.append(self.explain(data, **kwargs))
#     272 if kwargs.get("gc_collect", False):
#     273     gc.collect()
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\shap\explainers\_kernel.py:476, in KernelExplainer.explain(self, incoming_instance, **kwargs)
#     473     self.kernelWeights[nfixed_samples:] *= weight_left / self.kernelWeights[nfixed_samples:].sum()
#     475 # execute the model on the synthetic samples we have created
# --> 476 self.run()
#     478 # solve then expand the feature importance (Shapley value) vector to contain the non-varying features
#     479 phi = np.zeros((self.data.groups_size, self.D))
#
# File c:\WorkSpace\Practice\env3\lib\site-packages\shap\explainers\_kernel.py:630, in KernelExplainer.run(self)
#     627     eyVal += self.y[i * self.N + j, :] * self.data.weights[j]
#     629 self.ey[i, :] = eyVal
# --> 630 self.nsamplesRun += 1
#
# KeyboardInterrupt:

# %%
""" # グラフプロット用の関数
def plot_feature_importance(Model):
    for model_name, features in Model.items():
        plt.figure(figsize=(10, 6))
        names, values = zip(*sorted(features.items(), key=lambda x: x[1], reverse=True))
        plt.barh(names, values, color='skyblue')
        plt.title(f"Feature Importance for Model: {model_name}")
        plt.xlabel("Permutation Importance")
        plt.ylabel("Features")
        plt.tight_layout()
        plt.show()

# グラフ描画
plot_feature_importance(PFIs) """
# Out:
# ' # グラフプロット用の関数\ndef plot_feature_importance(Model):\n    for model_name, features in Model.items():\n        plt.figure(figsize=(10, 6))\n        names, values = zip(*sorted(features.items(), key=lambda x: x[1], reverse=True))\n        plt.barh(names, values, color=\'skyblue\')\n        plt.title(f"Feature Importance for Model: {model_name}")\n        plt.xlabel("Permutation Importance")\n        plt.ylabel("Features")\n        plt.tight_layout()\n        plt.show()\n\n# グラフ描画\nplot_feature_importance(PFIs) '

# %%
# 各モデルのデータを取得し、共通する特徴量リストを取得
features = list(PFIs["log"].keys())
importance_log = [PFIs["log"].get(f, 0) for f in features]
importance_rf = [PFIs["rf"].get(f, 0) for f in features]
importance_gb = [PFIs["gb"].get(f, 0) for f in features]
importance_svm = [PFIs["svm"].get(f, 0) for f in features]
importance_knn = [PFIs["knn"].get(f, 0) for f in features]
importance_mlp = [PFIs["mlp"].get(f, 0) for f in features]
importance_nb = [PFIs["nb"].get(f, 0) for f in features]

# グラフ描画
x = np.arange(len(features))  # 各特徴量の位置
width = 0.2  # バーの幅

fig, ax = plt.subplots(figsize=(12*2, 8*2))

# 各モデルの棒グラフをプロット
ax.bar(x - 3*width, importance_log, width, label='Logistic Regression', color='skyblue')
ax.bar(x - 2*width, importance_rf, width, label='Random Forest', color='lightgreen')
ax.bar(x - width, importance_gb, width, label='Gradient Boosting', color='salmon')
ax.bar(x, importance_svm, width, label='SVM', color='gold')
ax.bar(x + width, importance_knn, width, label='KNN', color='navy')
ax.bar(x + 2*width, importance_mlp, width, label='MLP', color='aqua')
ax.bar(x + 3*width, importance_nb, width, label='Naive Bayse', color='olive')

# 軸ラベルや目盛設定
ax.set_xlabel('Features', fontsize=12)
ax.set_ylabel('Permutation Importance', fontsize=12)
ax.set_title('Feature Importance Across Models', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(features, rotation=90, fontsize=10)
ax.legend()

plt.tight_layout()
plt.show()

# %%
# # 結果の記録
# basemodel_names = [name for name, _ in base_models]

# import datetime
# currenttime = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

# """ Accuracy = accuracy_score(y_test, y_pred)
# Precision = precision_score(y_test, y_pred, average='weighted')
# Recall = recall_score(y_test, y_pred, average='weighted')
# F1_Score = f1_score(y_test, y_pred, average='weighted') """

# model_list = random_search.best_estimator_.estimators
# Models = {}
# for name, _ in model_list:
#     Models[f"{name}"] = f"{name}"



# result = {'Original Data shape': [X.shape],
#             'sfs_model' : [sfs_model],
#             'Models': [basemodel_names],
#             'Best number of features': len(sfs.k_feature_idx_),
#             'Slected Features': [selected_features],
#             'Model Params':[random_search.best_params_],
#             'Accuracy': accuracy_score(y_test, y_pred),
#             'Precision': precision_score(y_test, y_pred, average='weighted'),
#             'Recall': recall_score(y_test, y_pred, average='weighted'),
#             'F1_Score' : f1_score(y_test, y_pred, average='weighted'),
#             'Date': currenttime,
#             'Dataset' : file_path
#             }

# save_importances = {
#                     'model' : Models,
#                     'PFI' : PFIs,
#                     # 'SHAP' : SHAPs,
#                     'Date': currenttime
#                     }

# new_result = pd.DataFrame(result)
# new_result.to_csv('C:/WorkSpace/Practice/卒研B/result2.csv',
#                   mode='a',
#                   header=False,
#                   index=False)

# new_importances = pd.DataFrame(save_importances)
# new_importances.to_csv('C:/WorkSpace/Practice/卒研B/importances.csv',
#                   mode='a',
#                   header=True,
#                   index=False)

# %%
# 結果の記録
basemodel_names = [name for name, _ in base_models]

import datetime
currenttime = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

""" Accuracy = accuracy_score(y_test, y_pred)
Precision = precision_score(y_test, y_pred, average='weighted')
Recall = recall_score(y_test, y_pred, average='weighted')
F1_Score = f1_score(y_test, y_pred, average='weighted') """

model_list = random_search.best_estimator_.estimators
Models = {}
for name, _ in model_list:
    Models[f"{name}"] = f"{name}"



result = {'Original Data shape': [X.shape],
            'sfs' : sfs,
            'Models': [basemodel_names],
            'Best number of features': len(selected_features),
            'Slected Features': [selected_features],
            'Model Params':[random_search.best_params_],
            'Model Accuravy':[Model_accuracy],
            'Accuracy': accuracy_score(y_test, y_pred),
            'Precision': precision_score(y_test, y_pred, average='weighted'),
            'Recall': recall_score(y_test, y_pred, average='weighted'),
            'F1_Score' : f1_score(y_test, y_pred, average='weighted'),
            'Date': currenttime,
            'Dataset' : file_path
            }

save_importances = {
                    'model' : Models,
                    'PFI' : PFIs,
                    # 'SHAP' : SHAPs,
                    'Date': currenttime
                    }

new_result = pd.DataFrame(result)
new_result.to_csv('C:/WorkSpace/Practice/卒研B/result4.csv',
                  mode='a',
                  header=False,
                  index=False)

new_importances = pd.DataFrame(save_importances)
new_importances.to_csv('C:/WorkSpace/Practice/卒研B/importances4.csv',
                  mode='a',
                  header=True,
                  index=False)

# %%
random_search.best_estimator_.estimators
# Out:
# [('log', LogisticRegression(C=2, max_iter=59, random_state=42)),
#  ('rf',
#   RandomForestClassifier(criterion='log_loss', max_depth=18,
#                          min_samples_leaf=0.14919802461752985, n_estimators=103,
#                          random_state=42)),
#  ('gb',
#   GradientBoostingClassifier(learning_rate=0.13089405362954842, max_depth=4,
#                              min_samples_leaf=3, n_estimators=81, random_state=42,
#                              subsample=0.7236144344963112)),
#  ('svm',
#   SVC(C=82.94324051412838, gamma=0.1, probability=True, random_state=42)),
#  ('knn', KNeighborsClassifier(leaf_size=23)),
#  ('mlp',
#   MLPClassifier(alpha=0.0058516335049662496, max_iter=153, random_state=42)),
#  ('nb', GaussianNB())]

# %%
import time
for i in range(5):
    print(i)
    time.sleep(1)
# !rundll32 user32.dll,MessageBeep
# Out:
# 0
# 1
# 2
# 3
# 4
