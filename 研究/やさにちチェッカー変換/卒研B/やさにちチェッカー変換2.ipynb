# %%
# %pip install chardet
# Out:
# Collecting chardetNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/199.4 kB ? eta -:--:--
#    ---------------------------------------  194.6/199.4 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 199.4/199.4 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: chardet
# Successfully installed chardet-5.2.0

# %%
import csv
import chardet
import os

def detect_encoding(file_path):
    with open(file_path, 'rb') as file:
        raw_data = file.read()
    return chardet.detect(raw_data)['encoding']

def extract_columns(input_file, output_file, columns):
    input_encoding = detect_encoding(input_file)
    print(f"処理中: {input_file} (エンコーディング: {input_encoding})")

    with open(input_file, 'r', encoding=input_encoding) as infile, \
         open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        reader = csv.reader(infile, delimiter='\t')
        writer = csv.writer(outfile)

        for row in reader:
            extracted_row = [row[i] for i in columns if i < len(row)]
            writer.writerow(extracted_row)

def process_files(input_dir, output_dir, columns):
    if not os.path.exists(input_dir):
        print(f"入力ディレクトリ '{input_dir}' が存在しません。")
        return

    os.makedirs(output_dir, exist_ok=True)

    txt_files = [f for f in os.listdir(input_dir) if f.endswith('.txt')]

    if not txt_files:
        print(f"ディレクトリ '{input_dir}' 内にtxtファイルが見つかりません。")
        return

    for txt_file in txt_files:
        input_file = os.path.join(input_dir, txt_file)
        output_file = os.path.join(output_dir, f"{os.path.splitext(txt_file)[0]}.csv")
        
        try:
            extract_columns(input_file, output_file, columns)
            print(f"抽出完了: {output_file}")
        except Exception as e:
            print(f"エラーが発生しました ({input_file}): {e}")

def main():
    input_dir = input("入力ファイルのディレクトリを入力してください: ")
    output_dir = input("出力ディレクトリを入力してください: ")
    columns_input = input("抽出したい列番号をカンマで区切って入力してください（0から始まります）: ")
    
    try:
        columns = [int(col.strip()) for col in columns_input.split(',')]
    except ValueError:
        print("無効な列番号です。整数を入力してください。")
        return

    process_files(input_dir, output_dir, columns)
    print("全てのファイルの処理が完了しました。")

if __name__ == "__main__":
    main()
# Out:
# 処理中: input\kekka (1).txt (エンコーディング: SHIFT_JIS)
# 抽出完了: output2\kekka (1).csv
# 処理中: input\kekka (2).txt (エンコーディング: SHIFT_JIS)
# 抽出完了: output2\kekka (2).csv
# 処理中: input\kekka (3).txt (エンコーディング: SHIFT_JIS)
# 抽出完了: output2\kekka (3).csv
# 処理中: input\kekka.txt (エンコーディング: SHIFT_JIS)
# 抽出完了: output2\kekka.csv
# 全てのファイルの処理が完了しました。

# %%
import csv
import chardet
import os
import codecs

def detect_encoding(file_path):
    with open(file_path, 'rb') as file:
        raw_data = file.read()
    return chardet.detect(raw_data)['encoding']

def extract_columns(input_file, output_file, columns):
    input_encoding = detect_encoding(input_file)
    print(f"処理中: {input_file} (エンコーディング: {input_encoding})")

    with open(input_file, 'r', encoding=input_encoding) as infile, \
         codecs.open(output_file, 'w', encoding='cp932', errors='ignore') as outfile:
        # BOM (Byte Order Mark) を追加
        outfile.write('\ufeff')
        
        reader = csv.reader(infile, delimiter='\t')
        writer = csv.writer(outfile, lineterminator='\n')

        for row in reader:
            extracted_row = [row[i] for i in columns if i < len(row)]
            writer.writerow(extracted_row)

def process_files(input_dir, output_dir, columns):
    if not os.path.exists(input_dir):
        print(f"入力ディレクトリ '{input_dir}' が存在しません。")
        return

    os.makedirs(output_dir, exist_ok=True)

    txt_files = [f for f in os.listdir(input_dir) if f.endswith('.txt')]

    if not txt_files:
        print(f"ディレクトリ '{input_dir}' 内にtxtファイルが見つかりません。")
        return

    for txt_file in txt_files:
        input_file = os.path.join(input_dir, txt_file)
        output_file = os.path.join(output_dir, f"{os.path.splitext(txt_file)[0]}.csv")
        
        try:
            extract_columns(input_file, output_file, columns)
            print(f"抽出完了: {output_file}")
        except Exception as e:
            print(f"エラーが発生しました ({input_file}): {e}")

def main():
    input_dir = input("入力ファイルのディレクトリを入力してください: ")
    output_dir = input("出力ディレクトリを入力してください: ")
    columns_input = input("抽出したい列番号をカンマで区切って入力してください（0から始まります）: ")
    
    try:
        columns = [int(col.strip()) for col in columns_input.split(',')]
    except ValueError:
        print("無効な列番号です。整数を入力してください。")
        return

    process_files(input_dir, output_dir, columns)
    print("全てのファイルの処理が完了しました。")

if __name__ == "__main__":
    main()
# Out:
# 処理中: input\kekka (1).txt (エンコーディング: SHIFT_JIS)
# 抽出完了: output3\kekka (1).csv
# 処理中: input\kekka (2).txt (エンコーディング: SHIFT_JIS)
# 抽出完了: output3\kekka (2).csv
# 処理中: input\kekka (3).txt (エンコーディング: SHIFT_JIS)
# 抽出完了: output3\kekka (3).csv
# 処理中: input\kekka.txt (エンコーディング: SHIFT_JIS)
# 抽出完了: output3\kekka.csv
# 全てのファイルの処理が完了しました。
