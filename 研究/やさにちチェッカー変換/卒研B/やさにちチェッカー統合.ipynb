# %%
import pandas as pd
import glob

# パスで指定したファイルの一覧をリスト形式で取得. （ここでは一階層下のtestファイル以下）
csv_files = glob.glob('C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46/*.csv')

#読み込むファイルのリストを表示
for a in csv_files:
    print(a)

#csvファイルの中身を追加していくリストを用意
data_list = []

#読み込むファイルのリストを走査
for file in csv_files:
    data_list.append(pd.read_csv(file, encoding='shift_jis'))

#リストを全て行方向に結合
#axis=0:行方向に結合, sort
df = pd.concat(data_list, axis=0, sort=True)

df.to_csv("C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\Moutput46.csv",index=False,encoding='shift_jis')
# Out:
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (1).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (10).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (11).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (12).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (13).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (14).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (15).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (16).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (17).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (18).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (19).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (2).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (20).csv
# C:\WorkSpace\Practice\研究\やさにちチェッカー変換\卒研B\output46\kekka (21).csv
# ...
