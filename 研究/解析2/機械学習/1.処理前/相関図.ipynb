# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\WorkSpace\Practice\研究\解析2\機械学習/1.処理前\SVR軽量版_視線情報.csv")

sns.scatterplot(x='Actual' , y='Predicted', data = df)
X = np.linspace(0, 80, 80)
Y = X
plt.plot(X, Y)

plt.xlabel("Actual", size = 25)
plt.ylabel("Predicted", size = 25)

plt.xticks([0, 20, 40, 60, 80])
plt.yticks([0, 20, 40, 60, 80])

plt.tick_params(labelsize=20)

plt.show()

# %%
df = pd.read_csv("C:\WorkSpace\Practice\研究\解析2\機械学習/1.処理前\SVR軽量版_視線情報.csv")

sns.scatterplot(x='Actual' , y='Predicted', data = df)
X = np.linspace(0, 80, 80)
Y = X
plt.plot(X, Y)

plt.xlabel("Actual", size = 25)
plt.ylabel("Predicted", size = 25)

plt.xticks([0, 0.2, 0.4, 0.6, 0.8])
plt.yticks([0, 0.2, 0.4, 0.6, 0.8])

plt.tick_params(labelsize=20)

plt.show()

# %%
df = pd.read_csv("C:\WorkSpace\Practice\研究\解析1\機械学習/1.処理前\SVR軽量版_視線情報 - コピー.csv")

sns.scatterplot(x='X_std' , y='Y_std', data = df)
X = np.linspace(-1.5, 3.5 , 100)
Y = X
plt.plot(X, Y)

plt.xlabel("Actual", size = 25)
plt.ylabel("Predicted", size = 25)

#plt.xticks([0, 20, 40, 60, 80])
#plt.yticks([0, 20, 40, 60, 80])

plt.tick_params(labelsize=20)

plt.show()

# %%
df = pd.read_csv("C:\WorkSpace\Practice\研究\解析1\機械学習/1.処理前\SVR軽量版_視線情報 - コピー.csv")

sns.scatterplot(x='X_100' , y='Y_100', data = df)
X = np.linspace(0, 1 , 100)
Y = X
plt.plot(X, Y)

plt.xlabel("Actual", size = 25)
plt.ylabel("Predicted", size = 25)

#plt.xticks([0, 20, 40, 60, 80])
#plt.yticks([0, 20, 40, 60, 80])

plt.tick_params(labelsize=20)

plt.show()
